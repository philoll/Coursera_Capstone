# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
#
# ### Part 1: Create dataframe

# %% [markdown]
# Importing the required packages for analysis.

# %%
# Import packages
import numpy as np
import pandas as pd

# %% [markdown]
# Using pandas to read the HTML file of the Wikipedia page and find all the tables. The *attrs* argument is passed to select only the tables with class **wikitable**. This returns a list. The first and only list item is converted into a pandas dataframe.

# %%
# Extract table from HTML
dlist = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M',
                     attrs = {'class': 'wikitable'}
                     )

# Create dataframe
df = dlist[0]

# %% [markdown]
# All rows with Borough that is **Not assigned** are removed from the table. All rows with Neighbourhood that is **Not assigned** but with an assigned borough are renamed to be the same as the borough (it should be noted that no rows meet this condition). All the indexes are reset.

# %%
# Remove not assigned boroughs
idx = df[df['Borough'] == 'Not assigned'].index
df.drop(idx, inplace = True)

# Rename not assigned neighbourhoods
df.loc[df['Neighbourhood'] == 'Not assigned', 'Neighbourhood'] = df['Borough']

# Reset index
df.reset_index(drop = True, inplace = True)
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# The number of rows in the dataframe are determined using the **.shape** method.

# %%
print('The dataframe has {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# The dataframe has 103 rows and 3 columns

# %% [markdown]
# # Part 2: Get coordinates

# %% [markdown]
# Importing the required package for analysis.

# %%
# Import packages
# !pip install geocoder
import geocoder

# %% [markdown]
# Using **geocoder** with the ArcGIS provider to find the coordinates of each postal code and save them to the dataframe. This is performed in a loop going over each row of the dataframe.

# %%
# Looping over each row (index) in the dataframe
for idx in range(0, df.shape[0]):

    # Initialize the variable for each postcode
    lat_lng_coords = None

    # Loop until the coordinates are retrieved using Geocoder
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(df.loc[idx,'Postal Code']))
        lat_lng_coords = g.latlng

    # Store the acquired coordinates in the dataframe
    df.loc[idx,'Latitude'] = lat_lng_coords[0]
    df.loc[idx,'Longitude'] = lat_lng_coords[1]

df.head()
# Out:
#   Postal Code           Borough  ...  Latitude  Longitude
# 0         M3A        North York  ...  43.75245  -79.32991
# 1         M4A        North York  ...  43.73057  -79.31306
# 2         M5A  Downtown Toronto  ...  43.65512  -79.36264
# 3         M6A        North York  ...  43.72327  -79.45042
# 4         M7A  Downtown Toronto  ...  43.66253  -79.39188
#
# [5 rows x 5 columns]

# %% [markdown]
# # Part 3: Analysis

# %% [markdown]
# Importing the required packages for analysis.

# %%
# Import packages
import matplotlib.cm as cm
import matplotlib.colors as colors
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans
import requests
import folium

# %% [markdown]
# Get coordinates for Toronto and create a map.

# %%
# Get coordinates of Toronto
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# Create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# Add markers to map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Define a function to get the nearby venues for each neighbourhood.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # Create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # Make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # Return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Create a dataframe with all the venues.

# %%
toronto_venues = getNearbyVenues(names=df['Neighbourhood'],
                                 latitudes=df['Latitude'],
                                 longitudes=df['Longitude']
                                )
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Queen's Park, Ontario Provincial Government
# Islington Avenue, Humber Valley Village
# Malvern, Rouge
# Don Mills
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# East Toronto, Broadview North (Old East York)
# ...

# %% [markdown]
# Analyse each neighbourhood by the type of venues.

# %%
# One hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# Move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# Group venues
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                        Neighborhood  ...  Women's Store
# 0                                         Agincourt  ...            0.0
# 1                            Alderwood, Long Branch  ...            0.0
# 2   Bathurst Manor, Wilson Heights, Downsview North  ...            0.0
# 3                                   Bayview Village  ...            0.0
# 4                 Bedford Park, Lawrence Manor East  ...            0.0
# ..                                              ...  ...            ...
# 92                      Willowdale, Willowdale West  ...            0.0
# 93                                           Woburn  ...            0.0
# 94                                 Woodbine Heights  ...            0.0
# 95                                  York Mills West  ...            0.0
# 96                         York Mills, Silver Hills  ...            0.0
#
# [97 rows x 259 columns]

# %% [markdown]
# Define a function to sort the venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Display the top 5 venues in each neighbourhood.

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood  ... 5th Most Common Venue
# 0                                        Agincourt  ...         Shopping Mall
# 1                           Alderwood, Long Branch  ...         Women's Store
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...           Fish Market
# 3                                  Bayview Village  ...     Fish & Chips Shop
# 4                Bedford Park, Lawrence Manor East  ...      Greek Restaurant
#
# [5 rows x 6 columns]

# %% [markdown]
# Cluster the neighbourhoods into 5 clusters and include the top venues into the dataframe.

# %%
# Set number of clusters
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# Add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df

# Merge toronto_grouped with df to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

toronto_merged.head()
# Out:
#   Postal Code           Borough  ... 4th Most Common Venue  5th Most Common Venue
# 0         M3A        North York  ...         Women's Store     Falafel Restaurant
# 1         M4A        North York  ...         Women's Store     Falafel Restaurant
# 2         M5A  Downtown Toronto  ...                   Pub                    Spa
# 3         M6A        North York  ...      Toy / Game Store             Restaurant
# 4         M7A  Downtown Toronto  ...    Italian Restaurant          Burrito Place
#
# [5 rows x 11 columns]

# %% [markdown]
# Visualise the clustering on a map.

# %%
# Create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    if np.isnan(cluster):
        continue
    else:
        label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[int(cluster)],
            fill=True,
            fill_color=rainbow[int(cluster)],
            fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Examine the clusters by looking at the most common venues.

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  ...  5th Most Common Venue
# 0          North York  ...     Falafel Restaurant
# 1          North York  ...     Falafel Restaurant
# 2    Downtown Toronto  ...                    Spa
# 3          North York  ...             Restaurant
# 4    Downtown Toronto  ...          Burrito Place
# ..                ...  ...                    ...
# 97   Downtown Toronto  ...                    Gym
# 99   Downtown Toronto  ...                Gay Bar
# 100      East Toronto  ...             Restaurant
# 101         Etobicoke  ...       Sushi Restaurant
# 102         Etobicoke  ...          Burrito Place
#
# [94 rows x 7 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 4th Most Common Venue 5th Most Common Venue
# 28  North York             1.0  ...           Flea Market           Fish Market
#
# [1 rows x 7 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels  ... 4th Most Common Venue 5th Most Common Venue
# 45       North York             2.0  ...           Flea Market           Fish Market
# 68  Central Toronto             2.0  ...           Flea Market           Fish Market
# 98        Etobicoke             2.0  ...           Flea Market           Fish Market
#
# [3 rows x 7 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Borough  ...        5th Most Common Venue
# 27    North York  ...  Eastern European Restaurant
# 69  West Toronto  ...  Eastern European Restaurant
#
# [2 rows x 7 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels  ... 4th Most Common Venue 5th Most Common Venue
# 12  Scarborough             4.0  ...           Flower Shop           Flea Market
#
# [1 rows x 7 columns]

# %% [markdown]
# It can be seen that the clusters are grouped by venue type:
#
# - 0 = Restaurant and Shopping
# - 1 = Businesses
# - 2 = Parks with shops
# - 3 = Parks with apartments
# - 4 = Bars
